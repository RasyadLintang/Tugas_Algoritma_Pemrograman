# %%
# Weekly Exercise 1 : Biodata
print('Nama         : Rasyad Lintang Wahyunindar')
print('')
print('NPM          : 2420506038')
print('')
print('Alamat       : Jl. Sunan Giri, Kota Magelang, Jawa Tengah')
print('')
print('Tinggi Badan : 165')
print('')
print('Berat Badan  : 50')
# Out:
# Nama         : Rasyad Lintang Wahyunindar
#
# NPM          : 2420506038
#
# Alamat       : Jl. Sunan Giri, Kota Magelang, Jawa Tengah
#
# Tinggi Badan : 165
#
# Berat Badan  : 50

# %%
# Weekly Exercise 2
print('\033[1m' + 'Universitas Tidar' + '\033[0m')
print('Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 tahun 2014')
print('')
print('\033[1m' + 'JURUSAN TEKNIK ELEKTRO, MEKATRONIKA, DAN INFORMASI' + '\033[0m')
print('Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:')
print(' 1. S1 Teknik Elektro \x1b[3m(Bachelor of Electrical Engineering)\x1b[0m')
print(' 2. S1 Teknologi Informasi \x1b[3m(Bachelor of Information Technology)\x1b[0m')
print(' 3. S1 Teknik Mekatronika \x1b[3m(Bachelor of Mechatronics Engineering)\x1b[0m')
# Out:
# Universitas Tidar
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 tahun 2014
#
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA, DAN INFORMASI
# Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:
#  1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
#  2. S1 Teknologi Informasi (Bachelor of Information Technology)
#  3. S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)
