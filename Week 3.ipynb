# %% [markdown]
# Weekly Exercise 1

# %%
# 1
with open('Week3.txt', 'w') as writefile:
  writefile.write("Nama : Rasyad Lintang Wahyunindar\n")
  writefile.write("Program Studi : Teknologi Informasi\n")
  writefile.write("NPM : 2420506038\n")
  writefile.write("Alamat : Jl. Sunan Giri, Kota Magelang, Jawa Tengah\n")
  writefile.write("Hobi : Bermain Game\n")
  writefile.write("Email : rasyadlintang15@gmail.com")

# %%
#2
with open('Week3.txt','r') as readfile:
  c = readfile.readlines()
  print(c[0])
  print(c[1])
  print(c[5])
# Out:
# Nama : Rasyad Lintang Wahyunindar
#
# Program Studi : Teknologi Informasi
#
# Email : rasyadlintang15@gmail.com

# %%
#3
with open('calldoc3.txt', 'w') as writefile:
  writefile.write(c[0])
  writefile.write(c[2])
  writefile.write(c[1])
  writefile.write(c[3])

# %%
with open('calldoc3.txt','r') as readfile:
  c = readfile.readlines()
  print(c[0])
  print(c[2])
  print(c[1])
  print(c[3])
# Out:
# Nama : Rasyad Lintang Wahyunindar
#
# Program Studi : Teknologi Informasi
#
# NPM : 2420506038
#
# Alamat : Jl. Sunan Giri, Kota Magelang, Jawa Tengah

# %% [markdown]
# Weekly Exercise 2

# %%
print("Selamat datang di Toko Maju Jaya")
print("Senin, 4 September 2023       13.05")
print(" ")
print("DAFTAR BELANJA:")
item1 = "Sabun"
item2 = 'Shampo'
item3 = 'Mie instant'
item4 = 'Detergen'
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500
total = harga1 + harga2 + harga3 + harga4
print(item1, "= Rp" + str(harga1))
print(item2, "= Rp" + str(harga2))
print(item3, "= Rp" + str(harga3))
print(item4, "= Rp" + str(harga4))
print(" ")
print("Total = Rp " + str(total))
print("")
with open('Kuitansi.txt', 'w') as writefile:
        writefile.write("Selamat Datang di Toko Maju Jaya\n")
        writefile.write(" \n")
        writefile.write("Kuitansi - 4 Septermber 2023\n")
        writefile.write(" \n")
        writefile.write(item1 + "= Rp " + str(harga1) + "\n")
        writefile.write(item2 + "= Rp " + str(harga2) + "\n")
        writefile.write(item3 + "= Rp " + str(harga3) + "\n")
        writefile.write(item4 + "= Rp " + str(harga4) + "\n")
        writefile.write(" \n")
        writefile.write("Total Belanja =" + str(total))
# Out:
# Selamat datang di Toko Maju Jaya
# Senin, 4 September 2023       13.05
#
# DAFTAR BELANJA:
# Sabun = Rp10000
# Shampo = Rp15000
# Mie instant = Rp5000
# Detergen = Rp17500
#
# Total = Rp 47500
